# %%
import stylecloud

stylecloud.gen_stylecloud(file_path='D:/Eliel Novelo/Documentos/8vo semestre/inteligencia artificial/PTW/tweets.txt',
                          icon_name='fas fa-user-secret',
                          colors='white',
                          background_color='black',
                          output_name='suicidio.png',
                          collocations=False)

# %% [markdown]
# stopwords

# %%
from stop_words import get_stop_words
palabras_irrelevantes = get_stop_words('spanish')
palabras_irrelevantes
# Out:
# ['a',
#  'al',
#  'algo',
#  'algunas',
#  'algunos',
#  'ante',
#  'antes',
#  'como',
#  'con',
#  'contra',
#  'cual',
#  'cuando',
#  'de',
#  'del',
#  'desde',
#  'donde',
#  'durante',
#  'e',
#  'el',
#  'ella',
#  'ellas',
#  'ellos',
#  'en',
#  'entre',
#  'era',
#  'erais',
#  'eran',
#  'eras',
#  'eres',
#  'es',
#  'esa',
#  'esas',
#  'ese',
#  'eso',
#  'esos',
#  'esta',
#  'estaba',
#  'estabais',
#  'estaban',
#  'estabas',
#  'estad',
#  'estada',
#  'estadas',
#  'estado',
#  'estados',
#  'estamos',
#  'estando',
#  'estar',
#  'estaremos',
#  'estará',
#  'estarán',
#  'estarás',
#  'estaré',
#  'estaréis',
#  'estaría',
#  'estaríais',
#  'estaríamos',
#  'estarían',
#  'estarías',
#  'estas',
#  'este',
#  'estemos',
#  'esto',
#  'estos',
#  'estoy',
#  'estuve',
#  'estuviera',
#  'estuvierais',
#  'estuvieran',
#  'estuvieras',
#  'estuvieron',
#  'estuviese',
#  'estuvieseis',
#  'estuviesen',
#  'estuvieses',
#  'estuvimos',
#  'estuviste',
# ...

# %%
stylecloud.gen_stylecloud(file_path='D:/Eliel Novelo/Documentos/8vo semestre/inteligencia artificial/PTW/tweets.txt',
                          icon_name='fas fa-user-secret',
                          colors='white',
                          background_color='black',
                          output_name='suicidio.png',
                          collocations=False,
                         custom_stopwords=palabras_irrelevantes)
